# %%
from celeste_embeddings import create_embedder

embedder = create_embedder("google")
embeddings = await embedder.generate_embeddings(["hello world", "bonjour"])
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
embeddings[0]
# Out:
# Embedding(values=[-0.024291614, 0.009657023, 0.00733815, -0.067482375, -0.0002838684, 0.0067863725, -0.015548599, 0.015049298, 0.009448663, 0.009580874, -0.006652876, -0.015874157, 0.031187186, 0.048733298, 0.108398154, 0.010618944, -0.004675663, -0.013690612, 0.0074243536, -0.009920813, 0.004850341, -0.009723427, 0.022108745, 0.014083462, -0.034320388, 0.0120006325, 0.023577124, 0.0040717004, 0.029236233, 0.018086793, 0.017370172, -0.011006943, -0.025254725, 0.00844105, -0.0063177105, 0.016223855, 0.011667513, 0.002438863, -0.011607857, -0.011513916, -0.00431477, 0.0106112715, -0.012091647, -0.012391565, -0.02004137, -0.016125549, -0.013181923, -0.012279317, -0.0037467428, 0.016318917, -0.029642595, -0.009967279, -0.005245735, -0.14974982, -0.010989837, 0.0056082206, -0.011868487, 0.028516477, -0.011966912, -0.018127374, -0.007480832, 0.004187261, -0.014855261, -0.0065974263, 0.003136884, -0.022624452, -0.012214766, 0.013775789, -0.025714833, 0.0022989272, 0.024730593, -0.0036059371
# ...

# %%
embeddings[0].__dict__.keys()
# Out:
# dict_keys(['values', 'usage', 'provider', 'metadata'])

# %%
embeddings[1].__dict__.keys()
# Out:
# dict_keys(['values', 'usage', 'provider', 'metadata'])
